# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/dataset.csv')

# %%
df1.head()
# Out:
#                                               review  rating
# 0            Всё норм. Мужу понравилось, как всегда.       5
# 1                      Все пришло попробовал отлично       5
# 2  Супер! Оригинал, выгодней намного чем в магази...       5
# 3  Шикарные лезвия, 4 штуки в упаковке (фоткала у...       5
# 4  На первый взгляд очень даже хорошие кассеты. П...       5

# %%
df1.rename(columns = {"review" : "text", "rating" : "label"}, inplace = True)

# %%
df1
# Out:
#                                                     text  label
# 0                Всё норм. Мужу понравилось, как всегда.      5
# 1                          Все пришло попробовал отлично      5
# 2      Супер! Оригинал, выгодней намного чем в магази...      5
# 3      Шикарные лезвия, 4 штуки в упаковке (фоткала у...      5
# 4      На первый взгляд очень даже хорошие кассеты. П...      5
# ...                                                  ...    ...
# 70078                         Для тренировок в сммый раз      5
# 70079                                      Хорошая майка      5
# 70080        Майка не понравилась-очень тонкий материал!      3
# 70081  На рост 190 см Вес 94 кг .подошел отлично разм...      5
# 70082  Материал очень приятный , качество хорошее , м...      5
#
# [70083 rows x 2 columns]

# %%
df1.loc[(df1.label <=3 ), 'label'] = 'negative'
df1.loc[(df1.label == 4), 'label'] = 'neutral'
df1.loc[(df1.label == 5), 'label'] = 'positive'

# %%
df1
# Out:
#                                                     text     label
# 0                Всё норм. Мужу понравилось, как всегда.  positive
# 1                          Все пришло попробовал отлично  positive
# 2      Супер! Оригинал, выгодней намного чем в магази...  positive
# 3      Шикарные лезвия, 4 штуки в упаковке (фоткала у...  positive
# 4      На первый взгляд очень даже хорошие кассеты. П...  positive
# ...                                                  ...       ...
# 70078                         Для тренировок в сммый раз  positive
# 70079                                      Хорошая майка  positive
# 70080        Майка не понравилась-очень тонкий материал!  negative
# 70081  На рост 190 см Вес 94 кг .подошел отлично разм...  positive
# 70082  Материал очень приятный , качество хорошее , м...  positive
#
# [70083 rows x 2 columns]

# %%
df1.label = df1.label.astype('str')
df1.label.dtypes
# Out:
# dtype('O')

# %%
df1.head()
# Out:
#                                                 text     label
# 0            Всё норм. Мужу понравилось, как всегда.  positive
# 1                      Все пришло попробовал отлично  positive
# 2  Супер! Оригинал, выгодней намного чем в магази...  positive
# 3  Шикарные лезвия, 4 штуки в упаковке (фоткала у...  positive
# 4  На первый взгляд очень даже хорошие кассеты. П...  positive

# %%
df1.dtypes
# Out:
# text     object
# label    object
# dtype: object

# %%
df1.to_csv('wildberries.csv', index = True, index_label = "id")

# %%
df2 = pd.read_excel('/content/Test_data_marked.xlsx')

# %%
df2
# Out:
#       Общая оценка  Цена/качество  Расположение  Качество сна  Номера  \
# 0              5.0            5.0           5.0           NaN     5.0
# 1              5.0            5.0           5.0           5.0     5.0
# 2              5.0            5.0           5.0           5.0     5.0
# 3              5.0            4.0           5.0           5.0     5.0
# 4              4.0            3.0           2.0           4.0     4.0
# ...            ...            ...           ...           ...     ...
# 6871           5.0            4.0           4.0           5.0     5.0
# 6872           5.0            5.0           4.0           5.0     5.0
# 6873           5.0            5.0           4.0           5.0     5.0
# 6874           5.0            5.0           5.0           5.0     5.0
# 6875           4.0            4.0           5.0           5.0     5.0
#
#       Чистота  Обслуживание                                       Текст отзыва
# ...

# %%
df3 = pd.read_excel('/content/Training_data_marked.xlsx')

# %%
df3.head()
# Out:
#    Unnamed: 0  Цена/качество  Расположение  Качество сна  Номера  Чистота  \
# 0           4            4.0           4.0           5.0     4.0      4.0
# 1           4            NaN           3.0           NaN     NaN      4.0
# 2           4            3.0           3.0           5.0     5.0      3.0
# 3           1            NaN           NaN           NaN     2.0      1.0
# 4           5            NaN           NaN           NaN     NaN      NaN
#
#    Обслуживание                                         Unnamed: 7
# 0           5.0  Очень достойный отель с прекрасными номерами, ...
# 1           4.0  Остановились в Барселоне проездом, т.к. нужно ...
# 2           4.0  Типичная сетевая гостиница. Главный плюс-шикар...
# 3           1.0  Начнем с того, что в этом отеле не берут деньг...
# 4           NaN  Отель находится в отдалении от центра,но пешко...

# %%
df3 = df3.rename(columns = {"Unnamed: 0":"Общая оценка", "Unnamed: 7":"Текст отзыва"})

# %%
df = pd.concat([df3, df2], ignore_index=True)

# %%
df
# Out:
#        Общая оценка  Цена/качество  Расположение  Качество сна  Номера  \
# 0               4.0            4.0           4.0           5.0     4.0
# 1               4.0            NaN           3.0           NaN     NaN
# 2               4.0            3.0           3.0           5.0     5.0
# 3               1.0            NaN           NaN           NaN     2.0
# 4               5.0            NaN           NaN           NaN     NaN
# ...             ...            ...           ...           ...     ...
# 56773           5.0            4.0           4.0           5.0     5.0
# 56774           5.0            5.0           4.0           5.0     5.0
# 56775           5.0            5.0           4.0           5.0     5.0
# 56776           5.0            5.0           5.0           5.0     5.0
# 56777           4.0            4.0           5.0           5.0     5.0
#
#        Чистота  Обслуживание  \
# 0          4.0           5.0
# 1          4.0           4.0
# ...

# %%
df_new = df[["Текст отзыва", "Общая оценка"]]

# %%
df_new.rename(columns ={"Текст отзыва":"text","Общая оценка":"label"}, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_new
# Out:
#                                                     text  label
# 0      Очень достойный отель с прекрасными номерами, ...    4.0
# 1      Остановились в Барселоне проездом, т.к. нужно ...    4.0
# 2      Типичная сетевая гостиница. Главный плюс-шикар...    4.0
# 3      Начнем с того, что в этом отеле не берут деньг...    1.0
# 4      Отель находится в отдалении от центра,но пешко...    5.0
# ...                                                  ...    ...
# 56773  Для нас было плюсом, что в этом отеле можно ос...    5.0
# 56774  Очень понравился отель.Хорошие номера с кухней...    5.0
# 56775  В Петербурге бываю очень часто, поэтому появле...    5.0
# 56776  Изумительное место! Я просто не ожидала такого...    5.0
# 56777  Останавливались в этом отеле в августе 2013, р...    4.0
#
# [56778 rows x 2 columns]

# %%
df_new.label.dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-224-adecc964aff0> in <module>
# ----> 1 df_new.label.dtype()
#
# TypeError: 'numpy.dtype[float64]' object is not callable

# %%
df_new.loc[(df_new.label <=3 ), 'label'] = 'negative'
df_new.loc[(df_new.label == 4), 'label'] = 'neutral'
df_new.loc[(df_new.label == 5), 'label'] = 'positive'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_new
# Out:
#                                                     text     label
# 0      Очень достойный отель с прекрасными номерами, ...   neutral
# 1      Остановились в Барселоне проездом, т.к. нужно ...   neutral
# 2      Типичная сетевая гостиница. Главный плюс-шикар...   neutral
# 3      Начнем с того, что в этом отеле не берут деньг...  negative
# 4      Отель находится в отдалении от центра,но пешко...  positive
# ...                                                  ...       ...
# 56773  Для нас было плюсом, что в этом отеле можно ос...  positive
# 56774  Очень понравился отель.Хорошие номера с кухней...  positive
# 56775  В Петербурге бываю очень часто, поэтому появле...  positive
# 56776  Изумительное место! Я просто не ожидала такого...  positive
# 56777  Останавливались в этом отеле в августе 2013, р...   neutral
#
# [56778 rows x 2 columns]

# %%
df_new.to_csv('hotel.csv', index = True, index_label = 'id')

# %%
df_drna = df.dropna()
df_drna = df_drna.reset_index(drop=True)

# %%
df_drna.head()
# Out:
#    Общая оценка  Цена/качество  Расположение  Качество сна  Номера  Чистота  \
# 0           4.0            4.0           4.0           5.0     4.0      4.0
# 1           4.0            3.0           3.0           5.0     5.0      3.0
# 2           5.0            4.0           4.0           5.0     5.0      5.0
# 3           5.0            5.0           4.0           5.0     5.0      5.0
# 4           4.0            4.0           3.0           5.0     5.0      5.0
#
#    Обслуживание                                       Текст отзыва
# 0           5.0  Очень достойный отель с прекрасными номерами, ...
# 1           4.0  Типичная сетевая гостиница. Главный плюс-шикар...
# 2           5.0  В сети отелей NH Collection отдыхаем впервые. ...
# 3           5.0  У отеля неплохое расположение, рядом есть разл...
# 4           5.0  Хороший отель, номера чистые, сервис на уровне...

# %%
df_drna['Общая оценка']
# Out:
# 0        4.0
# 1        4.0
# 2        5.0
# 3        5.0
# 4        4.0
#         ...
# 15717    5.0
# 15718    5.0
# 15719    5.0
# 15720    5.0
# 15721    4.0
# Name: Общая оценка, Length: 15722, dtype: float64

# %%
dff = df_drna[df_drna['Общая оценка'] <=3]
dff.drop("Общая оценка", axis=1, inplace=True)
dff = dff.reset_index(drop=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
dff.drop("Общая оценка", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-232-3827f937a39a> in <module>
# ----> 1 dff.drop("Общая оценка", axis=1, inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
dff[dff[["Цена/качество",	"Расположение",	"Качество сна",	"Номера",	"Чистота",	"Обслуживание"]]<=3]
# Out:
#       Цена/качество  Расположение  Качество сна  Номера  Чистота  \
# 0               3.0           NaN           NaN     3.0      NaN
# 1               3.0           3.0           NaN     NaN      NaN
# 2               3.0           NaN           2.0     2.0      3.0
# 3               NaN           NaN           NaN     3.0      NaN
# 4               2.0           NaN           NaN     3.0      NaN
# ...             ...           ...           ...     ...      ...
# 2346            1.0           1.0           1.0     1.0      3.0
# 2347            1.0           NaN           3.0     3.0      3.0
# 2348            3.0           3.0           NaN     NaN      NaN
# 2349            1.0           NaN           3.0     3.0      1.0
# 2350            1.0           1.0           NaN     1.0      1.0
#
#       Обслуживание Текст отзыва
# 0              NaN          NaN
# 1              NaN          NaN
# 2              2.0          NaN
# 3              NaN          NaN
# ...

# %%
dff.apply(lambda row: row[row <=3].index, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-234-097df14fdfb2> in <module>
# ----> 1 dff.apply(lambda row: row[row <=3].index, axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ...

# %%
dff["Цена/качество"]
# Out:
# 0       3.0
# 1       3.0
# 2       3.0
# 3       5.0
# 4       2.0
#        ...
# 2346    1.0
# 2347    1.0
# 2348    3.0
# 2349    1.0
# 2350    1.0
# Name: Цена/качество, Length: 2351, dtype: float64

# %%
df['Причина'] =
# Out:
#   File "<ipython-input-236-af5ffdd69f94>", line 1
#     df['Причина'] =
#                     ^
# SyntaxError: invalid syntax

# %%
dff.info()

# %%
dff

# %%
data = pd.read_csv('/content/data1.csv', error_bad_lines=False, engine="python", nrows=100000)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import csv

# %%
import pandas as pd

# %%
data1 = pd.read_csv('/content/data1.csv', encoding='utf-16 BE', header=0)

# %%
data1.head()

# %%
data2 = pd.read_csv('/content/data1.csv', error_bad_lines=False, engine="python", skiprows=200000,nrows=300000)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-261-cfdbfdfb5b4f> in <module>
# ----> 1 data2 = pd.read_csv('/content/data1.csv', error_bad_lines=False, engine="python", skiprows=200000,nrows=300000)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data3 = pd.read_csv('/content/data1.csv', error_bad_lines=False, engine="python",skiprows=300000, nrows=400000)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-262-2e155801376d> in <module>
# ----> 1 data3 = pd.read_csv('/content/data1.csv', error_bad_lines=False, engine="python",skiprows=300000, nrows=400000)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data4 = pd.read_csv('/content/data1.csv', error_bad_lines=False, engine="python", skiprows=400000)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-263-0a44dfa4ecbd> in <module>
# ----> 1 data4 = pd.read_csv('/content/data1.csv', error_bad_lines=False, engine="python", skiprows=400000)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data
# Out:
#                                                   Review  Rating
# 0      3D Touch просто восхитительная вещь! Заряд дер...       5
# 1      Отключается при температуре близкой к нулю, не...       4
# 2      В Apple окончательно решили не заморачиваться,...       3
# 3      Постарался наиболее ёмко и коротко описать все...       4
# 4      Достойный телефон. Пользоваться одно удовольст...       5
# ...                                                  ...     ...
# 99995  Не покупайте это Г. Ксениум уже не тот. Буду в...       3
# 99996  Хотелось иметь простую звонилку, но с выходом ...       4
# 99997  Купил 04.08 за 1.6кр доволен как слон))\rРазби...       4
# 99998  К сожалению производители телефонов, не только...       1
# 99999                    Отстой, больше Philips не куплю       2
#
# [100000 rows x 2 columns]

# %%
d = pd.read_csv("/content/cleaned_kaspi_reviews.csv", error_bad_lines=False, engine="python").drop(['index0', 'index1'], axis='columns')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
d
# Out:
#        language  rating    category  \
# 0       russian     5.0    perfumes
# 1       russian     5.0    perfumes
# 2       russian     5.0    perfumes
# 3        kazakh     5.0    perfumes
# 4       russian     4.0    perfumes
# ...         ...     ...         ...
# 119043  russian     5.0  headphones
# 119044  russian     4.0  headphones
# 119045  russian     5.0  headphones
# 119046  russian     4.0  headphones
# 119047  russian     5.0  headphones
#
#                                             combined_text
# 0       парфюм оригинальный . все ,  профессиональный ...
# 1       любимый dkny . запах просто шикарный . спасибо...
# 2       шикарный запах ! безумно нравиться ! не пожале...
# 3                                      иісі қатты ұнады .
# 4       запах просто классный ,  то ,  нужно летний вр...
# ...                                                   ...
# 119043  звук высокий средний ,  немного токсичный высо...
# ...

# %%
d= d[['rating', 'combined_text']]

# %%
d.rename(columns ={"rating": "label", "combined_text": "text"}, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
d.loc[(d.label <=3 ), 'label'] = 'negative'
d.loc[(d.label == 4), 'label'] = 'neutral'
d.loc[(d.label == 5), 'label'] = 'positive'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
d
# Out:
#            label                                               text
# 0       positive  парфюм оригинальный . все ,  профессиональный ...
# 1       positive  любимый dkny . запах просто шикарный . спасибо...
# 2       positive  шикарный запах ! безумно нравиться ! не пожале...
# 3       positive                                 иісі қатты ұнады .
# 4        neutral  запах просто классный ,  то ,  нужно летний вр...
# ...          ...                                                ...
# 119043  positive  звук высокий средний ,  немного токсичный высо...
# 119044   neutral  вполне сносный наушник ,  но ,  думать ,  не с...
# 119045  positive                               наушник просто супер
# 119046   neutral                             все супер бас маловато
# 119047  positive  отличный звук . система шумоподавление . качес...
#
# [119048 rows x 2 columns]

# %%
d.to_csv('rewiews.csv', index = True, index_label = 'id')

# %%
data

# %%
f = open('data2.txt','r')

# %%
f
# Out:
# <_io.TextIOWrapper name='data2.txt' mode='r' encoding='UTF-8'>

# %%
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-51-315c20b774c2> in <module>
# ----> 1 print(f.read())
#
# /usr/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xba in position 1048576: invalid start byte

# %%
paragraphs = f.split(',5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-a98820413f1a> in <module>
#       1 #s = 'Мой какой-то текст. ЭТо первый абзац.\n\nТут начинается второй абзац. И в нём два предложения.\n\n А это - третий, и он стосит из одного предложения.'
# ----> 2 paragraphs = f.split(',5')
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'split'

# %%
dfff = pd.read_csv("/content/women-clothing-accessories.3-class.balanced.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-67-e16b4636b6dc> in <module>
# ----> 1 dfff = pd.read_csv("/content/women-clothing-accessories.3-class.balanced.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv("/content/women-clothing-accessories.3-class.balanced_utf.csv", error_bad_lines=False, engine="python")
# Out:
# Skipping line 10: ',' expected after '"'
# Skipping line 25: ',' expected after '"'
# Skipping line 81: ',' expected after '"'
# Skipping line 111: ',' expected after '"'
# Skipping line 124: ',' expected after '"'
# Skipping line 140: ',' expected after '"'
# Skipping line 208: ',' expected after '"'
# Skipping line 211: ',' expected after '"'
# Skipping line 248: ',' expected after '"'
# Skipping line 254: ',' expected after '"'
# Skipping line 309: ',' expected after '"'
# Skipping line 341: ',' expected after '"'
# Skipping line 359: ',' expected after '"'
# Skipping line 425: ',' expected after '"'
# Skipping line 503: ',' expected after '"'
# Skipping line 537: ',' expected after '"'
# Skipping line 574: ',' expected after '"'
# Skipping line 676: ',' expected after '"'
# Skipping line 680: ',' expected after '"'
# Skipping line 695: ',' expected after '"'
# Skipping line 715: ',' expected after '"'
# Skipping line 729: ',' expected after '"'
# ...

# %%
df.rename(columns = {'review':'text',	'sentiment': 'label'}, inplace = True)

# %%
dfff = pd.read_csv("out.csv", error_bad_lines=False, engine="python")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dfff.rename(columns = {'Review':'text',	'Rating': 'label'}, inplace = True)

# %%
dfff.loc[(dfff.label <=3 ), 'label'] = 'negative'
dfff.loc[(dfff.label == 4), 'label'] = 'neutral'
dfff.loc[(dfff.label == 5), 'label'] = 'positive'

# %%
dfff
# Out:
#                                                      text     label
# 0       3D Touch просто восхитительная вещь! Заряд дер...  positive
# 1       Отключается при температуре близкой к нулю, не...   neutral
# 2       В Apple окончательно решили не заморачиваться,...  negative
# 3       Постарался наиболее ёмко и коротко описать все...   neutral
# 4       Достойный телефон. Пользоваться одно удовольст...  positive
# ...                                                   ...       ...
# 478913   часов разговоров, изредка пробки, инет очень ...  positive
# 478914  мой первый аппарат на андроиде. На данный моме...  positive
# 478915   часа wi-fi, 1 час разговоров, 1 час радио/мр3...  positive
# 478916  Разбил iphone и не было желания покупать новый...  positive
# 478917           Очень доволен покупкой и всем советую...  positive
#
# [478918 rows x 2 columns]

# %%
df_new.to_csv('phone.csv', index = True, index_label = 'id')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
women = pd.read_csv('drive/MyDrive/csv/women.csv', lineterminator='\n')

# %%
reviews = pd.read_csv('drive/MyDrive/csv/reviews.csv')

# %%
reviews.rename(columns = {'label': 'text', 'text': 'label'}, inplace = True)

# %%
reviews.to_csv('rewiews2.csv', index = False)

# %%
reviews
# Out:
#             id                                               text  label
# 0            0  парфюм оригинальный . все ,  профессиональный ...      1
# 1            1  любимый dkny . запах просто шикарный . спасибо...      1
# 2            2  шикарный запах ! безумно нравиться ! не пожале...      1
# 3            3                                 иісі қатты ұнады .      1
# 4            4  запах просто классный ,  то ,  нужно летний вр...      0
# ...        ...                                                ...    ...
# 119043  119043  звук высокий средний ,  немного токсичный высо...      1
# 119044  119044  вполне сносный наушник ,  но ,  думать ,  не с...      0
# 119045  119045                               наушник просто супер      1
# 119046  119046                             все супер бас маловато      0
# 119047  119047  отличный звук . система шумоподавление . качес...      1
#
# [119048 rows x 3 columns]

# %%
women.label.unique()
# Out:
# array(['-1', nan,
#        'negative  "2. Является ли товар таким же как на фотографии? ',
#        ' все фотографии реальны. Мы сделали эти фотографии сами.  ',
#        'neautral', '1',
#        'positive  "Один размер   на мои параметры рост 168 и ОГ 80 сел отлично. Плечи с рукавами на месте. ',
#        'positive  "It exceeded my expectations. Nice quality for the price. I am usually a smal'],
#       dtype=object)

# %%
women.dropna(inplace = True)

# %%
women.reset_index()
# Out:
#        index     id                                               text label
# 0          0      0  качество плохое пошив ужасный (горловина напер...    -1
# 1          1      1  Товар отдали другому человеку,   я не получила...    -1
# 2          2      2  Ужасная синтетика! Тонкая, ничего общего с пре...    -1
# 3          3      3  товар не пришел,   продавец продлил защиту без...    -1
# 4          4      4    Кофточка голая синтетика,   носить не возможно.    -1
# ...      ...    ...                                                ...   ...
# 84755  89009  89009  сделано достаточно хорошо. на ткани сделан рис...     1
# 84756  89010  89010  Накидка шикарная. Спасибо большое провдо линяе...     1
# 84757  89011  89011  спасибо большое ) продовца рекомендую.. заказа...     1
# 84758  89012  89012  Очень довольна заказом! Меньше месяца в РБ.  К...     1
# 84759  89013  89013  хорошая куртка. постороннего запаха нет. швы р...     1
#
# [84760 rows x 4 columns]

# %%
women.label.unique()
# Out:
# array(['-1',
#        'negative  "2. Является ли товар таким же как на фотографии? ',
#        ' все фотографии реальны. Мы сделали эти фотографии сами.  ',
#        'neautral', '1',
#        'positive  "Один размер   на мои параметры рост 168 и ОГ 80 сел отлично. Плечи с рукавами на месте. ',
#        'positive  "It exceeded my expectations. Nice quality for the price. I am usually a smal'],
#       dtype=object)

# %%
women[women.label == 'negative  "2. Является ли товар таким же как на фотографии? '].drop(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-29b88cea8b2b> in <module>
# ----> 1 women[women.label == 'negative  "2. Является ли товар таким же как на фотографии? '].drop(index)
#
# NameError: name 'index' is not defined

# %%
women = women[women.label != 'positive  "It exceeded my expectations. Nice quality for the price. I am usually a smal']

# %%
women.to_csv('women2.csv', index = False)

# %%
women.label.unique()
# Out:
# array(['-1', 0, '1'], dtype=object)

# %%
women.label = pd.to_numeric(women.label)

# %%
women.label.unique()
# Out:
# array([-1,  0,  1])

# %%
women
# Out:
#           id                                               text  label
# 0          0  качество плохое пошив ужасный (горловина напер...     -1
# 1          1  Товар отдали другому человеку,   я не получила...     -1
# 2          2  Ужасная синтетика! Тонкая, ничего общего с пре...     -1
# 3          3  товар не пришел,   продавец продлил защиту без...     -1
# 4          4    Кофточка голая синтетика,   носить не возможно.     -1
# ...      ...                                                ...    ...
# 89009  89009  сделано достаточно хорошо. на ткани сделан рис...      1
# 89010  89010  Накидка шикарная. Спасибо большое провдо линяе...      1
# 89011  89011  спасибо большое ) продовца рекомендую.. заказа...      1
# 89012  89012  Очень довольна заказом! Меньше месяца в РБ.  К...      1
# 89013  89013  хорошая куртка. постороннего запаха нет. швы р...      1
#
# [84756 rows x 3 columns]

# %%
women.loc[(women.label == 'neautral'), 'label'] = 0

# %%
women.label.unique()
# Out:
# array(['-1',
#        'negative  "2. Является ли товар таким же как на фотографии? ',
#        ' все фотографии реальны. Мы сделали эти фотографии сами.  ', 0,
#        '1',
#        'positive  "Один размер   на мои параметры рост 168 и ОГ 80 сел отлично. Плечи с рукавами на месте. ',
#        'positive  "It exceeded my expectations. Nice quality for the price. I am usually a smal'],
#       dtype=object)

# %%
women.drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c3440bb67221> in <module>
# ----> 1 women.drop()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4141         else:
#    4142             raise ValueError(
# ...

# %%
women.label.isna().sum()
# Out:
# 0

# %%
phone.label.isna().count()
# Out:
# 478918

# %%
phone.label.unique()
# Out:
# array([ 1,  0, -1])
